# %%
import pandas as pd
import numpy as np

# %%
evig = pd.read_excel('Irrigation Group list.xlsx',
                      workbook=0,
                      header = 4,
                      index_col=0
                      )
 
# Delete these row indexes from dataFrame
evig.dropna(axis=0, how='all', inplace=True)

# evig.set_index('Record ID')
evig['Geographic ID'] = evig['Geographic ID'].astype(str)
# evig['Record ID'] = evig['Record ID'].astype(int)
evig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 47 entries, 101.0 to 147.0
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Description            47 non-null     object
#  1   Acreage                46 non-null     float64
#  2   Owner                  46 non-null     object
#  3   e-mail                 41 non-null     object
#  4   phone                  36 non-null     object
#  5   Street Address         42 non-null     object
#  6   City, State, Zip       42 non-null     object
#  7   Mail Street            46 non-null     object
#  8   Mail City, State ZIP   46 non-null     object
#  9   Geographic ID          47 non-null     object
#  10  19Paid                 46 non-null     object
#  11  20paid                 30 non-null     object
# dtypes: float64(1), object(11)
# memory usage: 4.8+ KB

# %%
evig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 47 entries, 101.0 to 147.0
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Description            47 non-null     object
#  1   Acreage                46 non-null     float64
#  2   Owner                  46 non-null     object
#  3   e-mail                 41 non-null     object
#  4   phone                  36 non-null     object
#  5   Street Address         42 non-null     object
#  6   City, State, Zip       42 non-null     object
#  7   Mail Street            46 non-null     object
#  8   Mail City, State ZIP   46 non-null     object
#  9   Geographic ID          47 non-null     object
#  10  19Paid                 46 non-null     object
#  11  20paid                 30 non-null     object
# dtypes: float64(1), object(11)
# memory usage: 4.8+ KB

# %%
evig.drop(evig[evig['Description'] == 'Hillcrest'].index, inplace = True)
evig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 46 entries, 101.0 to 147.0
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Description            46 non-null     object
#  1   Acreage                46 non-null     float64
#  2   Owner                  46 non-null     object
#  3   e-mail                 41 non-null     object
#  4   phone                  36 non-null     object
#  5   Street Address         42 non-null     object
#  6   City, State, Zip       42 non-null     object
#  7   Mail Street            46 non-null     object
#  8   Mail City, State ZIP   46 non-null     object
#  9   Geographic ID          46 non-null     object
#  10  19Paid                 46 non-null     object
#  11  20paid                 30 non-null     object
# dtypes: float64(1), object(11)
# memory usage: 4.7+ KB

# %%
evig.to_csv('Roster.csv')

# %%
evig= pd.read_csv('Roster.csv', dtype={"Record ID": np.int64, "Geographic ID": np.object}, index_col=0)
evig.head()
# Out:
#              Description  Acreage                        Owner  \
# Record ID
# 101        Clenn Add #1      1.06     Jerome & Samantha Jerome
# 102         Clenn Add #2     1.06     Randy & Shawna Alexander
# 103         Clenn Add #3     1.02          Arlen & Donna Simon
# 104         Clenn Add #4     1.02  Ryan Jenkins & Kim Tobiason
# 105         Clenn Add #5     1.08         Steve & Patty Varner
#
#                                                  e-mail         phone  \
# Record ID
# 101        yakimadog@hotmail.com; roslyndog@hotmail.com  509-888-0358
# 102                                 alexfam@hotmail.com  509-548-2464
# 103                                 adsimon@televar.com  509-548-1344
# 104                              ryanandkim1@icloud.com  206-369-8651
# 105                                srv.1944@hotmail.com  509-548-7048
#
#                    Street Address       City, State, Zip  \
# Record ID
# 101         12310 Village View Dr  Leavenworth, WA 98826
# ...

# %%
evig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46 entries, 101 to 147
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Description            46 non-null     object
#  1   Acreage                46 non-null     float64
#  2   Owner                  46 non-null     object
#  3   e-mail                 41 non-null     object
#  4   phone                  36 non-null     object
#  5   Street Address         42 non-null     object
#  6   City, State, Zip       42 non-null     object
#  7   Mail Street            46 non-null     object
#  8   Mail City, State ZIP   46 non-null     object
#  9   Geographic ID          45 non-null     object
#  10  19Paid                 46 non-null     object
#  11  20paid                 30 non-null     object
# dtypes: float64(1), object(11)
# memory usage: 4.7+ KB

# %%
evig.to_csv('Roster.csv')

# %%
evig= pd.read_csv('Roster.csv', dtype={"Record ID": np.int64, "Geographic ID": np.object}, index_col=0)

evig
# Out:
#                Description  Acreage                             Owner  \
# Record ID
# 101          Clenn Add #1    1.0600          Jerome & Samantha Jerome
# 102           Clenn Add #2   1.0600          Randy & Shawna Alexander
# 103           Clenn Add #3   1.0200               Arlen & Donna Simon
# 104           Clenn Add #4   1.0200       Ryan Jenkins & Kim Tobiason
# 105           Clenn Add #5   1.0800              Steve & Patty Varner
# 106           Clenn Add #6   0.9200                Bill & Sally Bauer
# 107           Clenn Add #7   1.0300                     Marcia Patten
# 108           Clenn Add #8   0.9500  Scott Schimelfenig/Paula Strozyk
# 109           Clenn Add #9   0.9500            Larry & Deborah Jahnke
# 110          Clenn Add #10   0.9500         Nathan & Becca McLaughlin
# 111           SS2093 Lot 1   1.0000            Shirley DeCourcy Trust
# 112           SS2093 Lot 2   1.0000                      Carolyn Lord
# ...

# %%
evig['Geographic ID'] = evig['Geographic ID'].astype(str)
evig['Geographic ID'] = evig['Geographic ID'].apply(lambda x: x.replace('.0', ''))
evig.head()
# Out:
#              Description  Acreage                        Owner  \
# Record ID
# 101        Clenn Add #1      1.06     Jerome & Samantha Jerome
# 102         Clenn Add #2     1.06     Randy & Shawna Alexander
# 103         Clenn Add #3     1.02          Arlen & Donna Simon
# 104         Clenn Add #4     1.02  Ryan Jenkins & Kim Tobiason
# 105         Clenn Add #5     1.08         Steve & Patty Varner
#
#                                                  e-mail         phone  \
# Record ID
# 101        yakimadog@hotmail.com; roslyndog@hotmail.com  509-888-0358
# 102                                 alexfam@hotmail.com  509-548-2464
# 103                                 adsimon@televar.com  509-548-1344
# 104                              ryanandkim1@icloud.com  206-369-8651
# 105                                srv.1944@hotmail.com  509-548-7048
#
#                    Street Address       City, State, Zip  \
# Record ID
# 101         12310 Village View Dr  Leavenworth, WA 98826
# ...

# %%
evig.to_csv('Roster.csv')

# %%
evig = pd.read_csv('Roster.csv', dtype={"Record ID": np.int64, "Geographic ID": np.object}, index_col=0)
evig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46 entries, 101 to 147
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Description            46 non-null     object
#  1   Acreage                46 non-null     float64
#  2   Owner                  46 non-null     object
#  3   e-mail                 41 non-null     object
#  4   phone                  36 non-null     object
#  5   Street Address         42 non-null     object
#  6   City, State, Zip       42 non-null     object
#  7   Mail Street            46 non-null     object
#  8   Mail City, State ZIP   46 non-null     object
#  9   Geographic ID          45 non-null     object
#  10  19Paid                 46 non-null     object
#  11  20paid                 30 non-null     object
# dtypes: float64(1), object(11)
# memory usage: 4.7+ KB

# %%
evig.to_excel('Roster.xlsx')

# %%
evig = pd.read_excel('Roster.xlsx', dtype={"Record ID": np.int64, "Geographic ID": np.object}, index_col=0)
evig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46 entries, 101 to 147
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Description            46 non-null     object
#  1   Acreage                46 non-null     float64
#  2   Owner                  46 non-null     object
#  3   e-mail                 41 non-null     object
#  4   phone                  36 non-null     object
#  5   Street Address         42 non-null     object
#  6   City, State, Zip       42 non-null     object
#  7   Mail Street            46 non-null     object
#  8   Mail City, State ZIP   46 non-null     object
#  9   Geographic ID          45 non-null     object
#  10  19Paid                 46 non-null     object
#  11  20paid                 30 non-null     object
# dtypes: float64(1), object(11)
# memory usage: 4.7+ KB

# %%
evig.at[[113,111, 112, 114], '20paid'] = None
evig
# Out:
#                Description  Acreage                             Owner  \
# Record ID
# 101          Clenn Add #1    1.0600          Jerome & Samantha Jerome
# 102           Clenn Add #2   1.0600          Randy & Shawna Alexander
# 103           Clenn Add #3   1.0200               Arlen & Donna Simon
# 104           Clenn Add #4   1.0200       Ryan Jenkins & Kim Tobiason
# 105           Clenn Add #5   1.0800              Steve & Patty Varner
# 106           Clenn Add #6   0.9200                Bill & Sally Bauer
# 107           Clenn Add #7   1.0300                     Marcia Patten
# 108           Clenn Add #8   0.9500  Scott Schimelfenig/Paula Strozyk
# 109           Clenn Add #9   0.9500            Larry & Deborah Jahnke
# 110          Clenn Add #10   0.9500         Nathan & Becca McLaughlin
# 111           SS2093 Lot 1   1.0000            Shirley DeCourcy Trust
# 112           SS2093 Lot 2   1.0000                      Carolyn Lord
# ...
