# %%
import pandas as pd

# %%
members = pd.read_csv('members.csv')

# %%
members.head()
# Out:
#    Record ID    Description  Acreage                     Owner  \
# 0        101  Clenn Add #1      1.06  Jerome & Samantha Jerome
# 1        102   Clenn Add #2     1.06  Randy & Shawna Alexander
# 2        103   Clenn Add #3     1.02       Arlen & Donna Simon
# 3        104   Clenn Add #4     1.02        Ryan & Kim Jenkins
# 4        105   Clenn Add #5     1.08      Steve & Patty Varner
#
#                                          e-mail         phone  \
# 0  yakimadog@hotmail.com; roslyndog@hotmail.com  509-888-0358
# 1                           alexfam@hotmail.com  509-548-2464
# 2                           adsimon@televar.com  509-548-1344
# 3                        ryanandkim1@icloud.com  206-369-8651
# 4                          srv.1944@hotmail.com  509-548-7048
#
#            Street Address       City, State, Zip            Mail Street  \
# 0   12310 Village View Dr  Leavenworth, WA 98826  12310 Village View Dr
# ...

# %%
members.set_index('Record ID', inplace=True)

# %%
members.head()
# Out:
#              Description  Acreage                     Owner  \
# Record ID
# 101        Clenn Add #1      1.06  Jerome & Samantha Jerome
# 102         Clenn Add #2     1.06  Randy & Shawna Alexander
# 103         Clenn Add #3     1.02       Arlen & Donna Simon
# 104         Clenn Add #4     1.02        Ryan & Kim Jenkins
# 105         Clenn Add #5     1.08      Steve & Patty Varner
#
#                                                  e-mail         phone  \
# Record ID
# 101        yakimadog@hotmail.com; roslyndog@hotmail.com  509-888-0358
# 102                                 alexfam@hotmail.com  509-548-2464
# 103                                 adsimon@televar.com  509-548-1344
# 104                              ryanandkim1@icloud.com  206-369-8651
# 105                                srv.1944@hotmail.com  509-548-7048
#
#                    Street Address       City, State, Zip  \
# Record ID
# 101         12310 Village View Dr  Leavenworth, WA 98826
# ...

# %%
members['Owner']
# Out:
# Record ID
# 101            Jerome & Samantha Jerome
# 102            Randy & Shawna Alexander
# 103                 Arlen & Donna Simon
# 104                  Ryan & Kim Jenkins
# 105                Steve & Patty Varner
# 106                  Bill & Sally Bauer
# 107                       Marcia Patten
# 108    Scott Schimelfenig/Paula Strozyk
# 109              Larry & Deborah Jahnke
# 110           Nathan & Becca McLaughlin
# 111              Shirley DeCourcy Trust
# 112                        Carolyn Lord
# 113              Steve & Chelcie Strode
# 114              Jon & Margaret Wheeler
# 115               Dave & Barb Hambleton
# 116                     Easy Street LLC
# 117               Todd & Tracey Doherty
# 118                   Dan & Mary Nelson
# 119      Peter & Jennifer Kellogg-Smith
# 120                 Mark & Callie Baker
# 121                 Camp & Diane Fuller
# 122             Richard & Penny Aliulis
# 123           Susan Howard & Kari Bloss
# ...

# %%
members
# Out:
#                Description  Acreage                             Owner  \
# Record ID
# 101          Clenn Add #1    1.0600          Jerome & Samantha Jerome
# 102           Clenn Add #2   1.0600          Randy & Shawna Alexander
# 103           Clenn Add #3   1.0200               Arlen & Donna Simon
# 104           Clenn Add #4   1.0200                Ryan & Kim Jenkins
# 105           Clenn Add #5   1.0800              Steve & Patty Varner
# 106           Clenn Add #6   0.9200                Bill & Sally Bauer
# 107           Clenn Add #7   1.0300                     Marcia Patten
# 108           Clenn Add #8   0.9500  Scott Schimelfenig/Paula Strozyk
# 109           Clenn Add #9   0.9500            Larry & Deborah Jahnke
# 110          Clenn Add #10   0.9500         Nathan & Becca McLaughlin
# 111           SS2093 Lot 1   1.0000            Shirley DeCourcy Trust
# 112           SS2093 Lot 2   1.0000                      Carolyn Lord
# ...

# %%
df = members.to_json(orient='index')

# %%
df.to_json('members.json')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-303c64a007e0> in <module>
# ----> 1 df.to_json('members.json')
#
# AttributeError: 'str' object has no attribute 'to_json'

# %%
f = open('members.json', 'w')
f.write(df)
f.close()

# %%
f = open('members.json', 'r')
content = f.read()
# print(f.read())

# %%
content
# Out:
# '{"101":{"Description":"Clenn Add #1 ","Acreage":1.06,"Owner":"Jerome & Samantha Jerome","e-mail":"yakimadog@hotmail.com; roslyndog@hotmail.com","phone":"509-888-0358","Street Address":"12310 Village View Dr","City, State, Zip":"Leavenworth, WA 98826","Mail Street":"12310 Village View Dr","Mail City, State ZIP":"Leavenworth, WA 98826","Geographic ID":241701515010.0,"paid 2019":null},"102":{"Description":"Clenn Add #2","Acreage":1.06,"Owner":"Randy & Shawna Alexander","e-mail":"alexfam@hotmail.com","phone":"509-548-2464","Street Address":"12330 Village View Dr","City, State, Zip":"Leavenworth, WA 98826","Mail Street":"12330 Village View Dr","Mail City, State ZIP":"Leavenworth, WA 98826","Geographic ID":241701515020.0,"paid 2019":null},"103":{"Description":"Clenn Add #3","Acreage":1.02,"Owner":"Arlen & Donna Simon","e-mail":"adsimon@televar.com","phone":"509-548-1344","Street Address":"12360 Village View Dr.","City, State, Zip":"Leavenworth, WA 98826","Mail Street":"PO Box 291","Mail C
# ...
